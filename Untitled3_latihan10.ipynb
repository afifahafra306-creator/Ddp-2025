# %% [markdown]
# <a href="https://colab.research.google.com/github/afifahafra306-creator/Ddp-2025/blob/main/Untitled3_latihan10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile wakeRuang.py
import  math

def cube ( side ): result  =
    math.pow ( side,  3 ) return  result


def balok(p,l,t):
    hasil = p * l * t
    return hasil

def prism ( base ,  triangle_height ,  prism_height ):
    base_area =  0.5  * base * triangle_height
    result = base_area * prism_height return  result


print (prism( 3 , 3 , 3 ))
# Out:
# Overwriting bangunRuang.py

# %%
# %%writefile bangunDatar.py
import math
def jajarGenjar(alas, tinggi):
    return alas * tinggi
# Out:
# Overwriting bangunDatar.py

# %%
import bangunRuang as br
import bangunDatar as bd

print("~~~BANGUN RUANG~~~")
print(f"Volum Kubus dengan sisi 3 adalah {br.balok(4, 5,2) }")
print(f"Volum Prisma Segitiga adalah {br.prisma(5,4,5)}")
print(f"Volum Tabung adalah")
print(f"Volum Kerucut adalah")

print("~~BANGUN DATAR ~~")
print(f"Luas Persegi adalah ")
print(f"Luas Persegi Panjang adalah ")
print(f"Luas Segitiga adalah ")
print(f"Luas Lingkaran adalah ")
print(f"Luas JajarGenjar adalah {bd.jajarGenjar(4,7)} ")
# Out:
# ~~~BANGUN RUANG~~~
# Volum Kubus dengan sisi 3 adalah 40
# Volum Prisma Segitiga adalah 50.0
# Volum Tabung adalah
# Volum Kerucut adalah
# ~~BANGUN DATAR ~~
# Luas Persegi adalah
# Luas Persegi Panjang adalah
# Luas Segitiga adalah
# Luas Lingkaran adalah
# Luas JajarGenjar adalah 28
